# %% [markdown]
# ## Initial EDA

# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/from_mongo.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Season  Round           Race Name   Race Date  Race Time  \
# 0           0    1950      1  British Grand Prix  1950-05-13  10:10:00Z
# 1           1    1950      1  British Grand Prix  1950-05-13  10:10:00Z
# 2           2    1950      1  British Grand Prix  1950-05-13  10:10:00Z
# 3           3    1950      1  British Grand Prix  1950-05-13  10:10:00Z
# 4           4    1950      1  British Grand Prix  1950-05-13  10:10:00Z
#
#    Position  Points  Grid  Laps  ...         DOB Nationality  Constructor  \
# 0         1     9.0     1    70  ...  1906-10-30     Italian   Alfa Romeo
# 1         2     6.0     2    70  ...  1898-06-09     Italian   Alfa Romeo
# 2         3     4.0     4    70  ...  1911-07-02     British   Alfa Romeo
# 3         4     3.0     6    68  ...  1904-10-08      French  Talbot-Lago
# 4         5     2.0     9    68  ...  1905-11-05      French  Talbot-Lago
#
#   Constructor Nat         Circuit Name  \
# 0           Swiss  Silverstone Circuit
# ...

# %%
df.shape
# Out:
# (25780, 22)

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Season',
#  'Round',
#  'Race Name',
#  'Race Date',
#  'Race Time',
#  'Position',
#  'Points',
#  'Grid',
#  'Laps',
#  'Status',
#  'Driver',
#  'DOB',
#  'Nationality',
#  'Constructor',
#  'Constructor Nat',
#  'Circuit Name',
#  'Race Url',
#  'Lat',
#  'Long',
#  'Locality',
#  'Country']

# %%
df.drop('Unnamed: 0',inplace = True, axis = 1)

# %%
df.head()
# Out:
#    Season  Round           Race Name   Race Date  Race Time  Position  Points  \
# 0    1950      1  British Grand Prix  1950-05-13  10:10:00Z         1     9.0
# 1    1950      1  British Grand Prix  1950-05-13  10:10:00Z         2     6.0
# 2    1950      1  British Grand Prix  1950-05-13  10:10:00Z         3     4.0
# 3    1950      1  British Grand Prix  1950-05-13  10:10:00Z         4     3.0
# 4    1950      1  British Grand Prix  1950-05-13  10:10:00Z         5     2.0
#
#    Grid  Laps    Status  ...         DOB Nationality  Constructor  \
# 0     1    70  Finished  ...  1906-10-30     Italian   Alfa Romeo
# 1     2    70  Finished  ...  1898-06-09     Italian   Alfa Romeo
# 2     4    70  Finished  ...  1911-07-02     British   Alfa Romeo
# 3     6    68   +2 Laps  ...  1904-10-08      French  Talbot-Lago
# 4     9    68   +2 Laps  ...  1905-11-05      French  Talbot-Lago
#
#   Constructor Nat         Circuit Name  \
# 0           Swiss  Silverstone Circuit
# ...

# %%
df.isnull().sum()
# Out:
# Season             0
# Round              0
# Race Name          0
# Race Date          0
# Race Time          0
# Position           0
# Points             0
# Grid               0
# Laps               0
# Status             0
# Driver             0
# DOB                0
# Nationality        0
# Constructor        0
# Constructor Nat    0
# Circuit Name       0
# Race Url           0
# Lat                0
# Long               0
# Locality           0
# Country            0
# dtype: int64

# %%
df["Driver"]
# Out:
# 0             Nino Farina
# 1           Luigi Fagioli
# 2             Reg Parnell
# 3          Yves Cabantous
# 4            Louis Rosier
#                ...
# 25775    Daniel Ricciardo
# 25776     Nicholas Latifi
# 25777        Lance Stroll
# 25778     Valtteri Bottas
# 25779        Carlos Sainz
# Name: Driver, Length: 25780, dtype: object

# %%
df["Driver"].unique()
# Out:
# array(['Nino Farina', 'Luigi Fagioli', 'Reg Parnell', 'Yves Cabantous',
#        'Louis Rosier', 'Bob Gerard', 'Cuth Harrison',
#        'Philippe Étancelin', 'David Hampshire', 'Brian Shawe Taylor',
#        'Joe Fry', 'Johnny Claes', 'Juan Fangio', 'Joe Kelly',
#        'Prince Bira', 'David Murray', 'Geoff Crossley',
#        'Toulo de Graffenried', 'Louis Chiron', 'Eugène Martin',
#        'Peter Walker', 'Tony Rolt', 'Leslie Johnson', 'Alberto Ascari',
#        'Raymond Sommer', 'Luigi Villoresi', 'José Froilán González',
#        'Robert Manzon', 'Maurice Trintignant', 'Franco Rol',
#        'Harry Schell', 'Peter Whitehead', 'Alfredo Pián',
#        'Johnnie Parsons', 'Bill Holland', 'Mauri Rose', 'Cecil Green',
#        'Tony Bettenhausen', 'Joie Chitwood', 'Lee Wallard',
#        'Walt Faulkner', 'George Connor', 'Paul Russo', 'Pat Flaherty',
#        'Myron Fohr', 'Duane Carter', 'Mack Hellings', 'Jack McGrath',
# ...

# %%
len(df["Driver"].unique())
# Out:
# 855

# %% [markdown]
# ## There are total of 855 unique drivers

# %%
pd.DataFrame(df.columns)
# Out:
#                   0
# 0            Season
# 1             Round
# 2         Race Name
# 3         Race Date
# 4         Race Time
# 5          Position
# 6            Points
# 7              Grid
# 8              Laps
# 9            Status
# 10           Driver
# 11              DOB
# 12      Nationality
# 13      Constructor
# 14  Constructor Nat
# 15     Circuit Name
# 16         Race Url
# 17              Lat
# 18             Long
# 19         Locality
# 20          Country

# %%
df
# Out:
#        Season  Round                 Race Name   Race Date  Race Time  \
# 0        1950      1        British Grand Prix  1950-05-13  10:10:00Z
# 1        1950      1        British Grand Prix  1950-05-13  10:10:00Z
# 2        1950      1        British Grand Prix  1950-05-13  10:10:00Z
# 3        1950      1        British Grand Prix  1950-05-13  10:10:00Z
# 4        1950      1        British Grand Prix  1950-05-13  10:10:00Z
# ...       ...    ...                       ...         ...        ...
# 25775    2022     19  United States Grand Prix  2022-10-23  10:10:00Z
# 25776    2022     19  United States Grand Prix  2022-10-23  10:10:00Z
# 25777    2022     19  United States Grand Prix  2022-10-23  10:10:00Z
# 25778    2022     19  United States Grand Prix  2022-10-23  10:10:00Z
# 25779    2022     19  United States Grand Prix  2022-10-23  10:10:00Z
#
#        Position  Points  Grid  Laps            Status  ...         DOB  \
# ...
